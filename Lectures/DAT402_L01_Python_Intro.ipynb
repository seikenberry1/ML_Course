# %% [markdown]
# # Python Fundamentals
#
# Some familiarity with Python is assumed for this course, but we'll review some of the key features of Python, and introduce a little bit of regression as well!
#
# <img src="monty.jpg" alt="Monty Python!" style="width:550px;"/>
#
# #### Goals for this notebook:
#
# - Scalar types and mutability vs. immutability
# - Variable name binding
# - Advanced types: Lists, Tuples, Dictionaries, and Sets
#
# ---
#
# - List comprehensions
# - Sequence functions
#
# ---
#
# - Matplotlib fundamentals
#
# ---
#
# - Geopandas and pandas
# - Loading, cleaning, and **merging** data
# - Some simple regressions

# %% [markdown]
# #### Basic Libraries you should have:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
### We'll need this later in the course, so may as well install now:
import tensorflow as tf

# %% [markdown]
# ## Python Scalar Types
#
# There are several basic single value *scalar* types in the standard Python library:
#
#
# | Type | Description |
# | :- | :- |
# | `None` | NULL, Only a single instance of `None` exists
# | `str` | String, UTF-8 encoded strings
# | `bytes` | Raw ASCII bytes
# | `float` | Double-precision (64-bit) float (no separate `double` type)
# | `int` | Arbitrary precision signed integer
# | `bool` | `True` or `False` boolean
#
# **Scalar types are always *immutable***

# %%
#Make a float:
x = 1.1

#Look at the id in memory:
hex(id(x))
# Out:
# '0x1b334145e30'

# %%
#Now, do some arithmetic and look:
x = x + 1

#Different!
hex(id(x))
# Out:
# '0x1b334146c50'

# %%
# String are immutable:
#####

x = 'Monty'
y = 'Monty'

x is y
# Out:
# True

# %%
#And observe:
####

y = 'Monty'
print(hex(id(y)))

y = 'Monty' + ' Python'
print(hex(id(y)))
# Out:
# 0x1b317079c70
# 0x1b31707ad70

# %%
### And note the following fails:
y[0] = '!'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[383], line 2
#       1 ### And note the following fails:
# ----> 2 y[0] = '!'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## Typing and Variable Name Binding
#
# - Everything in Python, including functions, etc. is a Python object, and has an associated type and internal data.
#
#
# - Any time you assign a variable you are creating a *reference* to the object on the righthand side.  Assignment is also known as *binding*: **Binding a name to an object.**
#
#
# - Python is a **strongly typed language**:  objects still have types and implicit conversions only occur in obvious cases.
#
#
# - But the references to objects have no type, so you can do stuff like:

# %%
a = 5
print('I\'m a ', type(a), ', living at ', hex(id(a)))

a = 'I\'m a string now!'
print('I\'m a ', type(a), ', living at ', hex(id(a)))
# Out:
# I'm a  <class 'int'> , living at  0x1b365480170
# I'm a  <class 'str'> , living at  0x1b30c310ad0

# %% [markdown]
# ## Pass by reference/assignment
#
# Python uses "pass by assignment"
#
# - When passing variables to a function, *new local variables are created referencing the original objects*, without any copying
#
# - If you bind a new object to a passed variable within the function, the change is *not* reflected in the parent scope
#
# - However, you can alter *mutable* objects within the function and this *is* reflected in the parent scope
#
# For example:

# %%
def foo1(x):
    x = x + 1
    
y = 2
foo1(y)
print(y)
# Out:
# 2

# %%
def foo2(x):
    x = [1, 2, 3]

y = [2]
foo2(y)
print(y)
# Out:
# [2]

# %%
def foo3(x):
    #Compare:
    x = x + [99]
    
    #To:
    x.append(99)

y = [2]
foo3(y)
print(y)
# Out:
# [2]

# %% [markdown]
# ## Advanced variable types
#
# - Lists
# - Dictionaries
# - Tuples
# - Sets

# %% [markdown]
# ### Lists
#
# - Lists are an ordered array-like structure that is *mutable*. List elements can be of any type, including other lists, dictionary, and tuples
#
# - Essential to be comfortable with **list comprehensions**

# %%
## Recall some extending/appending on lists:
a = [1, 2, 3]
b = [4, 5, 6]

# %%
a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a + b*2
# Out:
# [1, 2, 3, 4, 5, 6, 4, 5, 6]

# %%
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a.append(b)
a
# Out:
# [1, 2, 3, 4, 5, 6, [4, 5, 6]]

# %% [markdown]
# ### Dictionaries
#
# Dictionaries are mutable list-like objects, declared using curly {}, define a set of key/value pairs

# %%
#Make a dictionary
my_dict = {'thing1':12.3, 'thing2':14, 'cat':'hat', 'yurtle':'turtle', 5:42}
my_dict
# Out:
# {'thing1': 12.3, 'thing2': 14, 'cat': 'hat', 'yurtle': 'turtle', 5: 42}

# %%
my_dict['thing1']
# Out:
# 12.3

# %% [markdown]
# ### Tuples
#
# Tuples are ordered, *immutable* array-like objects. Declare with parentheses `()` or nothing at all!
#
# - Recall tuple unpacking

# %%
#Can upack a tuple like so:
###

t = (4, 5, 6)

a, b, c = t
print(a,b,c)
# Out:
# 4 5 6

# %%
#For a nested tuple:
###

t = 4, 5, (6, 7)

a, b, c = t

print(a, b, c)
# Out:
# 4 5 (6, 7)

# %%
#OR

a, b, (c, d) = t
print(a, b, c, d)
# Out:
# 4 5 6 7

# %% [markdown]
# ### List Comprehension
#
# The basic form of a list comprehension is:
#
# ```
# [expr for val in collection if condition]
# ```
#
# Which is equivalent to:
#
# ```
# result = []
# for val in collection:
#     if condition:
#         result.append(expr)
# ```
#
# Don't necessarily need the condition, in which case we just append vals all together.

# %%
#Example: Square all odd numbers

[i**2 for i in [1,2,3,4,5] if i % 2 == 1]
# Out:
# [1, 9, 25]

# %% [markdown]
# ## Sequence Functions
#
# ### enumerate

# %%
#When we use a for loop, we loop over an iterable object
#Often want to track index. Can do easily with:
L = [1, 2, 3, "hey", range(3)]

for index, value in enumerate(L):
    print("Index " + str(index) + " has value: " + str(value))
# Out:
# Index 0 has value: 1
# Index 1 has value: 2
# Index 2 has value: 3
# Index 3 has value: hey
# Index 4 has value: range(0, 3)

# %% [markdown]
# ### zip
# `zip` pairs elements of other sequences to create a list of tuples:

# %%
#Example:

seq1 = [1, 2, 3]
seq2 = ["one", "two", "three"]

zipped = zip(seq1, seq2)
print(zipped)
# Out:
# <zip object at 0x000001B331DEBE40>

# %%
list(zipped)
# Out:
# [(1, 'one'), (2, 'two'), (3, 'three')]

# %% [markdown]
# ### list comprehension + zip for list arithmetic:

# %%
a = [1, 2, 3]
b = [4, 5, 6]

[(i + j) for i, j in zip(a,b)]
# Out:
# [5, 7, 9]

# %% [markdown]
# ## Also Remember:
#
# - Control structures (if/else, loops, etc.)
# - User-defined functions
# - Anonymous (lambda) functions

# %% [markdown]
# # Plotting in Matplotlib
#
# Let's review some of the fundamentals with plotting with matplotlib:
#
# - Basic plots
# - AxesSubplot/Axes object
# - Some customization
# - Advanced subplotting
# - Colormaps and custom colormaps
# - Annotation and text
# - Custom legends
# - Saving figures
#
# <img src="matplotlib.png" alt="Matplotlib" style="width:250px;"/>

# %%
#Bare bones plot:
#######

#
x = np.linspace(0,10,100)
y = x**2 + np.random.normal(0,10,100)

#And the very basic plot
plt.plot(x, y)

#Filter the data with a square filter (convolution):
#Adopted from StackOverflow: https://stackoverflow.com/questions/14313510/how-to-calculate-rolling-moving-average-using-python-numpy-scipy
def moving_average(x, w):
    return np.convolve(x, np.ones(w) / w, mode='same')
    
#Adds a plot to same figure:
plt.plot(x, moving_average(y, 5));

# %% [markdown]
# ### A Better Way: Use Axes/AxesSubplots
#
# - Main container/interface for plotted data, axis ticks, labels, title, legend, etc.
# - Use with multiple other plotting libraries that interface with matplotlib

# %%
#add_axes:
##########

fig = plt.figure(figsize=(6, 4))

#xmin,ymin,dx,dy
ax1 = fig.add_axes([0, 0, 1, 1])

ax1.plot(x,y)

#xmin,ymin,dx,dy
#Add a smaller inset axis
ax2 = fig.add_axes([.15, .6, .25, .25])

ax2.plot(x,y**2)
ax2.set_title('I\'m Little!', fontweight='bold')
ax2.set_xlabel('lil x')
ax2.set_ylabel('lil y')
# Out:
# Text(0, 0.5, 'lil y')

# %%
#Note: In latest version, need to install fiona and pyogrio BEFORE geopandas!
#####

#Some built-in geopandas teaching data:
#Recall we had:
import geopandas as gpd

#"gdf" is a common generic variable name = GeoDataFrame
gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Out:
# C:\Users\steff\AppData\Local\Temp\ipykernel_23688\2383556828.py:9: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
fig = plt.figure(figsize=(12, 6))

#xmin,ymin,dx,dyhttps://www.naturalearthdata.com/downloads/110m-cultural-vectors/
ax1 = fig.add_axes([0, 0, 1, 1])

#Plots a map automatically
gdf.plot(ax=ax1, column='pop_est')


#xmin,ymin,dx,dy
ax2 = fig.add_axes([.05, .25, .25, .25])
ax2.plot(x,y)

# %%
#Now let's inset a histogram of the population estimates:
##########

fig, ax1 = plt.subplots(1,1, figsize=(12, 10), dpi=300)

#Note the added alpha argument:
#Also, we'll use the LOG of population:
gdf.plot(ax = ax1, column = np.log10(gdf.pop_est), edgecolor='black', alpha=1, linewidth=1, cmap='jet')

#Make the inset_axes here:
axins = fig.add_axes([.15, .4, .15, .1])


if (0):
    n, bins, patches = axins.hist(gdf.pop_est, bins = 30, rwidth = 1, facecolor='red', \
                                edgecolor='black', linewidth = .5, alpha=0.75)

    #Set scale to LOG:
    axins.set_xscale('log')

else:
    my_bins = np.logspace(2,10,30)

    n, bins, patches = axins.hist(gdf.pop_est, bins = my_bins, rwidth = 1, facecolor='red', \
                                edgecolor='black', linewidth = .5, alpha=0.75)

    #Set scale to LOG:
    axins.set_xscale('log')
    
axins.set_title('Pop. Histogram: \n Log Scale', fontsize=10, fontweight='bold');

# %%
#Import and use make_axes_locatable:
######

from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax1 = plt.subplots(1,1, figsize=(12, 10), dpi=300)

#Pretty colorbar
divider = make_axes_locatable(ax1)
cax1 = divider.append_axes("right", size="2%", pad=0.1)

#Plot:
gdf.plot(ax=ax1, edgecolor='face', column='pop_est', cmap='jet', alpha=1,
                 legend=True, cax=cax1); #, legend_kwds={"orientation": "horizontal"})

# %% [markdown]
# ### Scatter Plots and AxesSubplot/Axes Objects

# %%
## Scatter Plots:

#Note the subplotting:

#We can make a "scatter plot" like this:
fig1, ax1 = plt.subplots(1, 2, figsize=(12, 6))

ax1[0].plot(x, y, 'o', markersize = 10, markerfacecolor='red', markeredgecolor='black', markeredgewidth=3)


#Or like this:
#Or use a designated scatter plot: 
ax1[1].scatter(x, y, c = y, s = np.sqrt(abs(y))*20 + 1, cmap='viridis', edgecolor='black')

# %%
type(ax1[0])
# Out:
# matplotlib.axes._axes.Axes

# %% [markdown]
# ### Some more subplotting

# %%
#Alternative subplot method
###########################

#Can set up grids of subplots using add_subplot:

#Start with a nice figure
fig = plt.figure(figsize=(10,6), dpi=90)

ax1 = fig.add_subplot(2, 2, 1) 
ax2 = fig.add_subplot(2, 2, 2)  
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# %%
#This style is more useful in creating custom grids:
#Example:

fig = plt.figure(figsize=(12,8))

ax1 = fig.add_subplot(4, 4, 1) 
ax2 = fig.add_subplot(4, 4, 2)
ax3 = fig.add_subplot(4, 4, 5)
ax4 = fig.add_subplot(4, 4, 6)

ax5 = fig.add_subplot(2, 2, 3)
ax6 = fig.add_subplot(1, 2, 2)


#Again, we can also adjust space around subplots:
###
plt.subplots_adjust(wspace=0.25, hspace=0.25)

#And add one title to rule them all!
####
plt.suptitle('There Can Be Only One', fontweight='bold', fontsize=18)
# Out:
# Text(0.5, 0.98, 'There Can Be Only One')

# %% [markdown]
# # Pandas Review
#
# - The `pandas` library is our fundamental library for working with tabular data/data frames.
#
# - Pandas is often used with numerical computing tools NumPy and SciPy, analytical libraries like scikit-learn, and data visualization libraries such as matplotlib
#
# - Adopts parts of NumPy's style for array-based computing and data processing without `for` loops
#
# <br>
#
# <img src="panda.png" alt="Panda!" style="width:375px;"/>
#
# <br>

# %% [markdown]
# ## Series
#
# The two fundamental data structures in pandas are the
#
# 1. **Series**
# 2. **DataFrame**
#
# A **Series** is a 1-D array-like object consisting of a sequence of values (types similar to NumPy types) + an array of data labels called its ***index***. Similar to a dictionary key:value pairing, but ordered.

# %%
#Example:

#Make a Series s with alphabetic index
s = pd.Series([1, 3, 5, 7, 9], index = list('abcde'))
s
# Out:
# a    1
# b    3
# c    5
# d    7
# e    9
# dtype: int64

# %% [markdown]
# ### Selection with loc and iloc
#
# Select subsets of rows and columns using either axis labels (`loc`) or integer index (`iloc`)
# - `loc`: Strictly label-based access
# - `iloc`: Strictly integer-based access

# %%
s.loc['a':'c']
# Out:
# a    1
# b    3
# c    5
# dtype: int64

# %%
s.iloc[0:2]
# Out:
# a    1
# b    3
# dtype: int64

# %% [markdown]
# ### Boolean Masking
#
# Similar to NumPy...
#
# **Note that masking, filtering, scalar multiplication, and math functions all preserve index-value link**

# %%
s > 3
# Out:
# a    False
# b    False
# c     True
# d     True
# e     True
# dtype: bool

# %%
s[s > 3]
# Out:
# c    5
# d    7
# e    9
# dtype: int64

# %%
#OR (better):
s.loc[s > 3]
# Out:
# c    5
# d    7
# e    9
# dtype: int64

# %% [markdown]
# ## DataFrame
#
# Rectangular table of data, where each column can be a different data type.
#
# - Both row and column index
# - Can also think of as a dictionary of Series that all share the same index (if you really want to)
#
# Consider our GeoDataFrame from above:

# %%
gdf.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
#Can do filtering with boolean masking:
######

gdf.loc[gdf.continent == 'North America']
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# 16    11263077.0  North America                     Haiti    HTI       14332
# 17    10738958.0  North America            Dominican Rep.    DOM       88941
# 19      389482.0  North America                   Bahamas    BHS       13578
# 22       56225.0  North America                 Greenland    GRL        3051
# 27   127575529.0  North America                    Mexico    MEX     1268870
# 33     4246439.0  North America                    Panama    PAN       66800
# 34     5047561.0  North America                Costa Rica    CRI       61801
# 35     6545502.0  North America                 Nicaragua    NIC       12520
# 36     9746117.0  North America                  Honduras    HND       25095
# 37     6453553.0  North America               El Salvador    SLV       27022
# 38    16604026.0  North America                 Guatemala    GTM       76710
# 39      390353.0  North America                    Belize    BLZ        1879
# 45     3193694.0  North America               Puerto Rico    PRI      104988
# 46     2948279.0  North America                   Jamaica    JAM       16458
# 47    11333483.0  North America                      Cuba    CUB      100023
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
#
#                                               geometry
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# 16   POLYGON ((-71.71236 19.71446, -71.62487 19.169...
# 17   POLYGON ((-71.70830 18.04500, -71.68774 18.316...
# 19   MULTIPOLYGON (((-78.98000 26.79000, -78.51000 ...
# 22   POLYGON ((-46.76379 82.62796, -43.40644 83.225...
# 27   POLYGON ((-117.12776 32.53534, -115.99135 32.6...
# 33   POLYGON ((-77.35336 8.67050, -77.47472 8.52429...
# 34   POLYGON ((-82.54620 9.56613, -82.93289 9.47681...
# 35   POLYGON ((-83.65561 10.93876, -83.89505 10.726...
# 36   POLYGON ((-83.14722 14.99583, -83.48999 15.016...
# 37   POLYGON ((-89.35333 14.42413, -89.05851 14.340...
# 38   POLYGON ((-92.22775 14.53883, -92.20323 14.830...
# 39   POLYGON ((-89.14308 17.80832, -89.15091 17.955...
# 45   POLYGON ((-66.28243 18.51476, -65.77130 18.426...
# 46   POLYGON ((-77.56960 18.49053, -76.89662 18.400...
# 47   POLYGON ((-82.26815 23.18861, -81.40446 23.117...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...

# %%
#Another example:
######

gdf.loc[(gdf.pop_est > 1e5) & (gdf.pop_est < 1e6)]
# Out:
#       pop_est      continent           name iso_a3  gdp_md_est  \
# 0    889953.0        Oceania           Fiji    FJI        5496
# 2    603253.0         Africa      W. Sahara    ESH         907
# 19   389482.0  North America        Bahamas    BHS       13578
# 39   390353.0  North America         Belize    BLZ        1879
# 41   782766.0  South America         Guyana    GUY        5173
# 42   581363.0  South America       Suriname    SUR        3697
# 89   299882.0        Oceania        Vanuatu    VUT         934
# 100  763092.0           Asia         Bhutan    BTN        2530
# 128  619896.0         Europe     Luxembourg    LUX       71104
# 134  287800.0        Oceania  New Caledonia    NCL       10770
# 135  669823.0        Oceania    Solomon Is.    SLB        1589
# 144  361313.0         Europe        Iceland    ISL       24188
# 149  433285.0           Asia         Brunei    BRN       13469
# 160  326000.0           Asia      N. Cyprus    CYN        3600
# 166  973560.0         Africa       Djibouti    DJI        3324
# 173  622137.0         Europe     Montenegro    MNE        5542
#
#                                               geometry
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 19   MULTIPOLYGON (((-78.98000 26.79000, -78.51000 ...
# 39   POLYGON ((-89.14308 17.80832, -89.15091 17.955...
# 41   POLYGON ((-56.53939 1.89952, -56.78270 1.86371...
# 42   POLYGON ((-54.52475 2.31185, -55.09759 2.52375...
# 89   MULTIPOLYGON (((167.21680 -15.89185, 167.84488...
# 100  POLYGON ((91.69666 27.77174, 92.10371 27.45261...
# 128  POLYGON ((6.04307 50.12805, 6.24275 49.90223, ...
# 134  POLYGON ((165.77999 -21.08000, 166.59999 -21.7...
# 135  MULTIPOLYGON (((162.11902 -10.48272, 162.39865...
# 144  POLYGON ((-14.50870 66.45589, -14.73964 65.808...
# 149  POLYGON ((115.45071 5.44773, 115.40570 4.95523...
# 160  POLYGON ((32.73178 35.14003, 32.80247 35.14550...
# 166  POLYGON ((42.35156 12.54223, 42.77964 12.45542...
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...

# %%
#If we grab columns, these are Series:
######

gdf['pop_est']
# Out:
# 0         889953.0
# 1       58005463.0
# 2         603253.0
# 3       37589262.0
# 4      328239523.0
#           ...
# 172      6944975.0
# 173       622137.0
# 174      1794248.0
# 175      1394973.0
# 176     11062113.0
# Name: pop_est, Length: 177, dtype: float64

# %%
#Unless we pass a list with a single item:
######

gdf[['pop_est']]
# Out:
#          pop_est
# 0       889953.0
# 1     58005463.0
# 2       603253.0
# 3     37589262.0
# 4    328239523.0
# ..           ...
# 172    6944975.0
# 173     622137.0
# 174    1794248.0
# 175    1394973.0
# 176   11062113.0
#
# [177 rows x 1 columns]

# %%
#To get as numpy:
######

gdf['pop_est'].values
# Out:
# array([8.89953000e+05, 5.80054630e+07, 6.03253000e+05, 3.75892620e+07,
#        3.28239523e+08, 1.85139300e+07, 3.35806500e+07, 8.77610900e+06,
#        2.70625568e+08, 4.49387120e+07, 1.89520380e+07, 8.67905670e+07,
#        1.01923173e+07, 5.25739730e+07, 4.28132380e+07, 1.59468760e+07,
#        1.12630770e+07, 1.07389580e+07, 1.44373535e+08, 3.89482000e+05,
#        3.39800000e+03, 5.34789600e+06, 5.62250000e+04, 1.40000000e+02,
#        1.29311900e+06, 5.85582700e+07, 2.12526800e+06, 1.27575529e+08,
#        3.46173400e+06, 2.11049527e+08, 1.15131000e+07, 3.25104530e+07,
#        5.03394430e+07, 4.24643900e+06, 5.04756100e+06, 6.54550200e+06,
#        9.74611700e+06, 6.45355300e+06, 1.66040260e+07, 3.90353000e+05,
#        2.85158290e+07, 7.82766000e+05, 5.81363000e+05, 6.70598870e+07,
#        1.73736620e+07, 3.19369400e+06, 2.94827900e+06, 1.13334830e+07,
#        1.46454680e+07, 2.30369700e+06, 2.49453000e+06, 1.62963640e+07,
#        1.96580310e+07, 4.52569600e+06, 1.18011510e+07, 2.33107150e+07,
#        2.00963599e+08, 2.58763800e+07, 8.08236600e+06, 3.04178560e+07,
#        2.57165440e+07, 1.27712460e+07, 1.92092200e+06, 4.93737400e+06,
#        7.81321500e+06, 2.03213780e+07, 4.74518500e+06, 5.38050800e+06,
#        2.17257900e+06, 1.35598600e+06, 1.78610300e+07, 1.86287470e+07,
#        3.03660360e+07, 1.14813000e+06, 3.18252950e+07, 1.15305800e+07,
#        9.05330000e+06, 6.85571300e+06, 2.69693070e+07, 4.68530600e+06,
#        2.34770600e+06, 1.16947190e+07, 4.30530540e+07, 1.01016940e+07,
#        9.77052900e+06, 2.83206700e+06, 4.20708300e+06, 3.93097830e+07,
#        4.97498600e+06, 2.99882000e+05, 1.64865420e+07, 6.96255820e+07,
#        7.16945500e+06, 5.40454200e+07, 9.64621060e+07, 2.56661610e+07,
#        5.17090980e+07, 3.22516700e+06, 1.36641775e+09, 1.63046161e+08,
#        7.63092000e+05, 2.86087100e+07, 2.16565318e+08, 3.80417540e+07,
#        9.32101800e+06, 6.45690000e+06, 5.94208900e+06, 8.29139060e+07,
#        1.70701350e+07, 2.95773100e+06, 1.02854530e+07, 9.46685600e+06,
#        4.43851550e+07, 3.79708740e+07, 8.87706700e+06, 9.76994900e+06,
#        2.65763700e+06, 1.93565440e+07, 2.78684400e+06, 1.91278900e+06,
#        1.32659000e+06, 8.31327990e+07, 6.97576100e+06, 1.07163220e+07,
#        8.34296150e+07, 2.85419100e+06, 4.06750000e+06, 8.57483200e+06,
#        6.19896000e+05, 1.14840550e+07, 1.73328500e+07, 1.02694170e+07,
#        4.70767810e+07, 4.94144400e+06, 2.87800000e+05, 6.69823000e+05,
#        4.91700000e+06, 2.53643070e+07, 2.18030000e+07, 1.39771500e+09,
#        2.35683780e+07, 6.02973960e+07, 5.81855300e+06, 6.68344050e+07,
#        3.61313000e+05, 1.00233180e+07, 3.72038200e+06, 1.08116615e+08,
#        3.19497770e+07, 4.33285000e+05, 2.08794600e+06, 5.52031400e+06,
#        5.45407300e+06, 1.06697090e+07, 6.08119600e+06, 1.26264931e+08,
#        7.04463600e+06, 2.91619220e+07, 3.42685280e+07, 4.49000000e+03,
#        3.26000000e+05, 1.19857500e+06, 3.64717690e+07, 1.00388073e+08,
#        6.77745200e+06, 1.12078730e+08, 9.73560000e+05, 5.09615900e+06,
#        4.42695940e+07, 1.26269500e+07, 3.30100000e+06, 2.08345900e+06,
#        6.94497500e+06, 6.22137000e+05, 1.79424800e+06, 1.39497300e+06,
#        1.10621130e+07])

# %%
### Also note:
gdf['pop_est'].values.shape
# Out:
# (177,)

# %%
gdf[['pop_est']].values.shape
# Out:
# (177, 1)

# %%
gdf['pop_est'].values.reshape(-1,1).shape
# Out:
# (177, 1)

# %% [markdown]
# ## Merging/Joining + Cleaning Data
#
# - We'll get a couple datasets on life satisfaction and GDP from the World Bank
# - Join with our maps dataframe
# - Do some cleaning

# %% [markdown]
# ## Get Life Satisfaction data from the OECD
#
# - https://stats.oecd.org/Index.aspx?DataSetCode=BLI
#
# - Let's download as a CSV file, and load with Pandas

# %%
#Call it df_bli:
df_bli = pd.read_csv('Data/BLI_Data.csv')

# %%
#What have we?
df_bli
# Out:
#      LOCATION         Country INDICATOR                          Indicator  \
# 0         AUS       Australia   JE_LMIS           Labour market insecurity
# 1         AUT         Austria   JE_LMIS           Labour market insecurity
# 2         BEL         Belgium   JE_LMIS           Labour market insecurity
# 3         CAN          Canada   JE_LMIS           Labour market insecurity
# 4         CZE  Czech Republic   JE_LMIS           Labour market insecurity
# ...       ...             ...       ...                                ...
# 2364      CRI      Costa Rica   PS_REPH                      Homicide rate
# 2365      CRI      Costa Rica   PS_REPH                      Homicide rate
# 2366      CRI      Costa Rica   WL_EWLH  Employees working very long hours
# 2367      CRI      Costa Rica   WL_EWLH  Employees working very long hours
# 2368      CRI      Costa Rica   WL_EWLH  Employees working very long hours
#
#      MEASURE Measure INEQUALITY Inequality Unit Code        Unit  \
# 0          L   Value        TOT      Total        PC  Percentage
# 1          L   Value        TOT      Total        PC  Percentage
# 2          L   Value        TOT      Total        PC  Percentage
# 3          L   Value        TOT      Total        PC  Percentage
# 4          L   Value        TOT      Total        PC  Percentage
# ...      ...     ...        ...        ...       ...         ...
# 2364       L   Value         MN        Men     RATIO       Ratio
# 2365       L   Value        WMN      Women     RATIO       Ratio
# 2366       L   Value        TOT      Total        PC  Percentage
# 2367       L   Value         MN        Men        PC  Percentage
# 2368       L   Value        WMN      Women        PC  Percentage
#
#       PowerCode Code PowerCode  Reference Period Code  Reference Period  \
# 0                  0     Units                    NaN               NaN
# 1                  0     Units                    NaN               NaN
# 2                  0     Units                    NaN               NaN
# 3                  0     Units                    NaN               NaN
# 4                  0     Units                    NaN               NaN
# ...              ...       ...                    ...               ...
# 2364               0     Units                    NaN               NaN
# 2365               0     Units                    NaN               NaN
# 2366               0     Units                    NaN               NaN
# 2367               0     Units                    NaN               NaN
# 2368               0     Units                    NaN               NaN
#
#       Value  Flag Codes  Flags
# 0       3.1         NaN    NaN
# 1       2.3         NaN    NaN
# 2       2.4         NaN    NaN
# 3       3.8         NaN    NaN
# 4       2.3         NaN    NaN
# ...     ...         ...    ...
# 2364   18.2         NaN    NaN
# 2365    1.8         NaN    NaN
# 2366   22.0         NaN    NaN
# 2367   27.9         NaN    NaN
# 2368   12.7         NaN    NaN
#
# [2369 rows x 17 columns]

# %%
#What type of columns do we have?
#Note that this itself is a Series
df_bli.dtypes
# Out:
# LOCATION                  object
# Country                   object
# INDICATOR                 object
# Indicator                 object
# MEASURE                   object
# Measure                   object
# INEQUALITY                object
# Inequality                object
# Unit Code                 object
# Unit                      object
# PowerCode Code             int64
# PowerCode                 object
# Reference Period Code    float64
# Reference Period         float64
# Value                    float64
# Flag Codes               float64
# Flags                    float64
# dtype: object

# %%
##
type(df_bli.dtypes)
# Out:
# pandas.core.series.Series

# %%
## Unique Indicators?
df_bli.Indicator.unique()
# Out:
# array(['Labour market insecurity',
#        'Stakeholder engagement for developing regulations',
#        'Dwellings without basic facilities', 'Housing expenditure',
#        'Feeling safe walking alone at night', 'Rooms per person',
#        'Household net adjusted disposable income', 'Household net wealth',
#        'Employment rate', 'Long-term unemployment rate',
#        'Personal earnings', 'Quality of support network',
#        'Educational attainment', 'Student skills', 'Years in education',
#        'Air pollution', 'Water quality', 'Voter turnout',
#        'Life expectancy', 'Self-reported health', 'Life satisfaction',
#        'Homicide rate', 'Employees working very long hours',
#        'Time devoted to leisure and personal care'], dtype=object)

# %%
## Let's look at "Life satisfaction"
df_bli.loc[df_bli.Indicator == 'Life satisfaction']
# Out:
#      LOCATION         Country INDICATOR          Indicator MEASURE Measure  \
# 1722      AUS       Australia   SW_LIFS  Life satisfaction       L   Value
# 1723      AUT         Austria   SW_LIFS  Life satisfaction       L   Value
# 1724      BEL         Belgium   SW_LIFS  Life satisfaction       L   Value
# 1725      CAN          Canada   SW_LIFS  Life satisfaction       L   Value
# 1726      CZE  Czech Republic   SW_LIFS  Life satisfaction       L   Value
# ...       ...             ...       ...                ...     ...     ...
# 2358      CRI      Costa Rica   SW_LIFS  Life satisfaction       L   Value
# 2359      CRI      Costa Rica   SW_LIFS  Life satisfaction       L   Value
# 2360      CRI      Costa Rica   SW_LIFS  Life satisfaction       L   Value
# 2361      CRI      Costa Rica   SW_LIFS  Life satisfaction       L   Value
# 2362      CRI      Costa Rica   SW_LIFS  Life satisfaction       L   Value
#
#      INEQUALITY Inequality Unit Code           Unit  PowerCode Code PowerCode  \
# 1722        TOT      Total   AVSCORE  Average score               0     Units
# 1723        TOT      Total   AVSCORE  Average score               0     Units
# 1724        TOT      Total   AVSCORE  Average score               0     Units
# 1725        TOT      Total   AVSCORE  Average score               0     Units
# 1726        TOT      Total   AVSCORE  Average score               0     Units
# ...         ...        ...       ...            ...             ...       ...
# 2358        TOT      Total   AVSCORE  Average score               0     Units
# 2359         MN        Men   AVSCORE  Average score               0     Units
# 2360        WMN      Women   AVSCORE  Average score               0     Units
# 2361        HGH       High   AVSCORE  Average score               0     Units
# 2362         LW        Low   AVSCORE  Average score               0     Units
#
#       Reference Period Code  Reference Period  Value  Flag Codes  Flags
# 1722                    NaN               NaN    7.1         NaN    NaN
# 1723                    NaN               NaN    7.2         NaN    NaN
# 1724                    NaN               NaN    6.8         NaN    NaN
# 1725                    NaN               NaN    7.0         NaN    NaN
# 1726                    NaN               NaN    6.9         NaN    NaN
# ...                     ...               ...    ...         ...    ...
# 2358                    NaN               NaN    6.3         NaN    NaN
# 2359                    NaN               NaN    6.2         NaN    NaN
# 2360                    NaN               NaN    6.5         NaN    NaN
# 2361                    NaN               NaN    7.1         NaN    NaN
# 2362                    NaN               NaN    6.5         NaN    NaN
#
# [208 rows x 17 columns]

# %%
#Looks like "Inequality" can be either "Men," "Women," or "Total"
#Let's filter down to just Total
df_filtered = df_bli.loc[df_bli.Indicator == 'Life satisfaction'].loc[df_bli.Inequality == 'Total']

# %%
#What's our shape?
df_filtered.shape
# Out:
# (42, 17)

# %%
#And our locations?
#Note we have OECD as one
df_filtered[['LOCATION', 'Country']]
# Out:
#      LOCATION          Country
# 1722      AUS        Australia
# 1723      AUT          Austria
# 1724      BEL          Belgium
# 1725      CAN           Canada
# 1726      CZE   Czech Republic
# 1727      DNK          Denmark
# 1728      FIN          Finland
# 1729      FRA           France
# 1730      DEU          Germany
# 1731      GRC           Greece
# 1732      HUN          Hungary
# 1733      ISL          Iceland
# 1734      IRL          Ireland
# 1735      ITA            Italy
# 1736      JPN            Japan
# 1737      KOR            Korea
# 1738      LUX       Luxembourg
# 1739      MEX           Mexico
# 1740      NLD      Netherlands
# 1741      NZL      New Zealand
# 1742      NOR           Norway
# 1743      POL           Poland
# 1744      PRT         Portugal
# 1745      SVK  Slovak Republic
# 1746      ESP            Spain
# 1747      SWE           Sweden
# 1748      CHE      Switzerland
# 1749      TUR          Türkiye
# 1750      GBR   United Kingdom
# 1751      USA    United States
# 1752      BRA           Brazil
# 1753      CHL            Chile
# 1754      EST          Estonia
# 1755      ISR           Israel
# 1756      LVA           Latvia
# 1757      RUS           Russia
# 1758      SVN         Slovenia
# 1759      ZAF     South Africa
# 1760     OECD     OECD - Total
# 2298      COL         Colombia
# 2299      LTU        Lithuania
# 2358      CRI       Costa Rica

# %% [markdown]
# ## Merge to Map!
#
# Let's do an **inner** vs. **left** join:

# %%
### The merge/join:
gdf_merged = gdf.merge(df_filtered, left_on='iso_a3', right_on='LOCATION', how='left')

# %%
gdf_merged.shape
# Out:
# (177, 23)

# %%
#Let's plot the Value:
fig, ax1 = plt.subplots(1,1, figsize=(12, 10), dpi=300)

divider = make_axes_locatable(ax1)
cax1 = divider.append_axes("right", size="2%", pad=0.1)

gdf_merged.plot(ax = ax1, column = 'Value', edgecolor='black', alpha=1, linewidth=.5, cmap='Greens',
                missing_kwds={"color": "lightgrey", "edgecolor": "darkred", "hatch": "", "label": "Missing values"},
                cax=cax1, legend=True);

ax1.set_axis_off()

# %%
#Make a New column for GDP per capita:
#############

gdf_merged['GDP_Per_Cap'] = gdf_merged.gdp_md_est / gdf_merged.pop_est * 1e6

# %%
#Make another GeoDataFrame that drops all the NA
#Also sort by GDP_Per_Cap:
gdf_merged_noNaN = gdf_merged.dropna(subset = ['Value']).sort_values(by = 'GDP_Per_Cap')

# %%
#And let's see how these correlate:

#Note, we size by population and color by Value:
plt.scatter(gdf_merged_noNaN.GDP_Per_Cap, gdf_merged_noNaN.Value, s=gdf_merged_noNaN.pop_est/1e6, c=gdf_merged_noNaN.Value)
plt.xlabel('Per Capita GDP ($)')
plt.ylabel('Life Satisfaction')
# Out:
# Text(0, 0.5, 'Life Satisfaction')

# %% [markdown]
# ### Get and Clean World Bank Data Too
#
# - Before we move onto regression and a few more plots, let's get some World Bank data on per capita GDP
# - We'll intentionally dirty this data a little bit first, just so we can practice cleaning it
# - Reintroduce `apply()` and `applymap()` methods

# %%
#Note the header argument:
df_wb = pd.read_csv('Data/GDP_World_Bank.csv', header=4)

# %%
#See what we got:
#####

df_wb
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  GDP per capita (current US$)
# 1    Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                    Afghanistan          AFG  GDP per capita (current US$)
# 3     Africa Western and Central          AFW  GDP per capita (current US$)
# 4                         Angola          AGO  GDP per capita (current US$)
# ..                           ...          ...                           ...
# 261                       Kosovo          XKX  GDP per capita (current US$)
# 262                  Yemen, Rep.          YEM  GDP per capita (current US$)
# 263                 South Africa          ZAF  GDP per capita (current US$)
# 264                       Zambia          ZMB  GDP per capita (current US$)
# 265                     Zimbabwe          ZWE  GDP per capita (current US$)
#
#      Indicator Code        1960        1961        1962        1963  \
# 0    NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN
# 1    NY.GDP.PCAP.CD  161.638982  161.111657  170.538537  198.038919
# 2    NY.GDP.PCAP.CD   62.369375   62.443703   60.950364   82.021738
# 3    NY.GDP.PCAP.CD  107.423775  112.503866  118.197351  122.774120
# 4    NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN
# ..              ...         ...         ...         ...         ...
# 261  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN
# 262  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN
# 263  NY.GDP.PCAP.CD  529.561923  543.042224  560.699395  601.599951
# 264  NY.GDP.PCAP.CD  228.567398  216.274674  208.562685  209.453362
# 265  NY.GDP.PCAP.CD  276.643363  279.332656  275.966139  277.532515
#
#            1964        1965  ...          2013          2014          2015  \
# 0           NaN         NaN  ...  26515.678080  26942.307980  28421.386490
# 1    178.019217  196.818756  ...   1736.222507   1724.534381   1545.559084
# 2     85.511073  105.243196  ...    651.987862    628.146804    592.476165
# 3    131.163760  137.809818  ...   2153.766138   2247.857492   1880.750778
# 4           NaN         NaN  ...   5101.983876   5059.080441   3100.830685
# ..          ...         ...  ...           ...           ...           ...
# 261         NaN         NaN  ...   3704.562199   3902.529820   3520.780421
# 262         NaN         NaN  ...   1497.747941   1557.601406   1488.416267
# 263  642.688431  681.131112  ...   7441.230854   6965.137897   6204.929901
# 264  236.941713  296.022427  ...   1840.320553   1724.576220   1307.909649
# 265  282.376856  294.893605  ...   1408.367810   1407.034291   1410.329173
#
#              2016          2017          2018          2019          2020  \
# 0    28451.273740  29326.708060  30918.515220  31902.762580  24487.863570
# 1     1436.094404   1613.668488   1550.111762   1499.954437   1353.927527
# 2      520.251955    530.149863    502.057099    500.522981    516.866797
# 3     1646.972399   1588.581005   1732.816544   1810.538006   1686.997899
# 4     1709.515534   2283.214233   2487.500996   2142.238757   1502.950754
# ..            ...           ...           ...           ...           ...
# 261   3759.471040   4009.356038   4384.190404   4416.031322   4310.932984
# 262   1069.816997    893.716573    701.714878    693.816484    583.875663
# 263   5735.066787   6734.475153   7048.508112   6688.774746   5741.641249
# 264   1249.923143   1495.752138   1475.199836   1268.120941    956.831748
# 265   1421.787791   1192.107012   2269.177012   1421.868596   1372.696674
#
#              2021         2022
# 0    29342.100730          NaN
# 1     1539.165543  1622.391720
# 2      363.674087          NaN
# 3     1765.965307  1790.348800
# 4     1903.717405  2998.501158
# ..            ...          ...
# 261   5269.783901  5351.439542
# 262    603.707959   676.928385
# 263   7055.055176  6776.480077
# 264   1137.344395  1487.907764
# 265   1773.920411  1266.996031
#
# [266 rows x 67 columns]

# %%
#Now, let's add commas and dollar signs in the year columns:
########

#We can add commas like so:
####
format(df_wb['2022'].values[1], ',f')
# Out:
# '1,622.391720'

# %%
#Do it to everything in one column:
########

df_wb['2022'].apply(lambda x: format(x, ',f'))[0]
# Out:
# 'nan'

# %%
##And to all of the columns:
#######

df_wb.loc[:,'1960':'2022'] = df_wb.loc[:,'1960':'2022'].applymap(lambda x: format(x, ',f'))

# %%
#Now we have objects (strings):
df_wb.dtypes
# Out:
# Country Name      object
# Country Code      object
# Indicator Name    object
# Indicator Code    object
# 1960              object
#                    ...
# 2018              object
# 2019              object
# 2020              object
# 2021              object
# 2022              object
# Length: 67, dtype: object

# %%
#And now, let's add dollar signs!
########

df_wb.loc[:,'1960':'2022'] = df_wb.loc[:,'1960':'2022'].applymap(lambda x: '$' + x if x != 'nan' else x)

# %%
## And save our intentionally inferior data back to file:
#########

#Note the index=False argument
df_wb.to_csv('Data/GDP_World_Bank_Dirty.csv', index=False)

# %% [markdown]
# ### Load and Clean:
#
# We'll strip out the $ and , and then convert to a float/numeric

# %%
df_wb = pd.read_csv('Data/GDP_World_Bank_Dirty.csv')

# %%
#Note we actually get a mix of types when we load back in:
x = df_wb['1960'].values
x
# Out:
# array([nan, '$161.638982', '$62.369375', '$107.423775', nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, '$1,810.597443', '$935.460427', nan,
#        '$71.360224', '$1,273.691659', '$90.035831', '$69.083195',
#        '$84.825334', nan, nan, '$1,483.003682', nan, nan, '$307.128629',
#        '$1,902.402119', '$101.690810', '$232.998762', nan, nan, nan,
#        '$59.297122', '$66.770095', '$2,259.288302', nan, '$1,787.360378',
#        nan, '$504.801138', '$89.520218', '$147.277834', '$120.018194',
#        '$219.905827', '$124.782359', '$256.962847', nan, nan,
#        '$376.968786', '$446.724344', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, '$203.879751', '$239.033006', '$90.719212',
#        '$153.477606', '$148.212965', nan, nan, '$448.114882', nan,
#        '$923.044701', nan, '$396.392253', nan, nan, nan, nan,
#        '$1,179.353011', '$279.534498', '$1,333.881573', nan, nan,
#        '$275.585338', '$1,397.594863', nan, '$176.116376', nan, nan, nan,
#        nan, nan, '$520.322744', nan, nan, '$252.756171', nan,
#        '$297.586044', '$1,371.948030', '$424.056554', '$161.477559',
#        '$105.794012', nan, '$70.027548', nan, '$164.280860',
#        '$152.861457', '$97.351448', '$100.212992', nan, '$99.197386', nan,
#        '$83.035102', nan, '$685.614712', '$196.323927', '$237.684588',
#        '$1,414.983281', '$1,365.752714', '$804.492623', '$425.653769',
#        nan, '$475.319075', nan, '$102.079868', nan, '$114.972955', nan,
#        '$218.260426', '$158.274637', nan, '$350.119120', nan, nan, nan,
#        nan, nan, '$384.765743', nan, nan, nan, '$144.101854',
#        '$97.294914', '$146.426324', '$46.866638', '$171.493638', nan,
#        '$2,242.015817', nan, nan, nan, '$172.599320', nan, nan,
#        '$132.670284', nan, nan, '$359.545059', nan, '$150.125172', nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        '$244.611029', '$2,939.446607', nan, nan, '$128.530591',
#        '$93.397048', '$126.962817', '$1,068.784587', '$1,441.755660',
#        '$49.993840', nan, '$2,312.949992', '$1,330.480243', nan, nan,
#        '$81.586947', '$476.621422', '$252.844498', '$263.837060', nan,
#        '$116.079964', nan, '$110.105829', '$717.514843', nan,
#        '$360.499299', nan, nan, nan, '$1,386.723037', nan, nan, nan, nan,
#        '$40.119192', '$82.558349', nan, '$100.262199', '$306.641642',
#        '$428.056183', nan, '$139.917539', nan, nan, '$62.861994', nan,
#        '$136.141900', nan, '$136.164974', nan, nan, '$371.279751', nan,
#        nan, '$2,114.003030', '$101.652865', nan, '$288.058159',
#        '$186.024287', nan, '$103.537481', '$91.798996', nan, '$99.677149',
#        '$103.800959', nan, nan, '$379.626944', nan, nan, nan,
#        '$82.558349', '$136.164974', '$632.388916', nan, '$274.525692',
#        nan, nan, '$55.529337', nan, '$190.842811', '$491.213493',
#        '$3,007.123445', nan, '$155.294494', '$939.560806', nan, nan, nan,
#        nan, '$456.826375', nan, nan, nan, '$529.561923', '$228.567398',
#        '$276.643363'], dtype=object)

# %%
#We have floats (NaNs)
type(x[0])
# Out:
# float

# %%
#And strings:
type(x[1])
# Out:
# str

# %%
#Object data type:
x.dtype
# Out:
# dtype('O')

# %%
#Can get rid of $ and commas like so:
#########

df_wb['2020'].apply(lambda x: x.replace('$','').replace(',','') if type(x) == str else np.NaN)
# Out:
# 0      24487.863570
# 1       1353.927527
# 2        516.866797
# 3       1686.997899
# 4       1502.950754
#            ...
# 261     4310.932984
# 262      583.875663
# 263     5741.641249
# 264      956.831748
# 265     1372.696674
# Name: 2020, Length: 266, dtype: object

# %%
#Or, a little easier, and for all:
#########

df_wb.loc[:,'1960':'2022'] = df_wb.loc[:,'1960':'2022'].replace({'\$':'', ',':''}, regex=True)

# %%
###And now we can convert everything to a float:
#######

#This doesn't work
#df_wb.loc[:,'1960':'2022'] = df_wb.loc[:,'1960':'2022'].astype(np.float64)

#This does:
df_wb[df_wb.columns[4:]] = df_wb[df_wb.columns[4:]].astype(np.float64)

# %%
###Alternative:
#######

df_wb[df_wb.columns[4:]] = df_wb[df_wb.columns[4:]].applymap(pd.to_numeric)

#df_wb.loc[:,'1960':'2022'] = df_wb.loc[:,'1960':'2022'].applymap(pd.to_numeric)

# %%
#We get, for example:
df_wb['2022']
# Out:
# 0              NaN
# 1      1622.391720
# 2              NaN
# 3      1790.348800
# 4      2998.501158
#           ...
# 261    5351.439542
# 262     676.928385
# 263    6776.480077
# 264    1487.907764
# 265    1266.996031
# Name: 2022, Length: 266, dtype: float64

# %% [markdown]
# ### Merge Again and Plot, Again
#
# - Left join GDP onto our map

# %%
#Let's do a left join:

gdf_merged2 = gdf_merged.merge(df_wb, left_on = 'iso_a3', right_on = 'Country Code', how = 'left')

# %%
gdf_merged2.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry LOCATION        Country  \
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...      NaN            NaN
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...      NaN            NaN
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...      NaN            NaN
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...      CAN         Canada
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...      USA  United States
#
#   INDICATOR          Indicator  ...          2013          2014          2015  \
# 0       NaN                NaN  ...   4586.956165   5305.063400   5105.190039
# 1       NaN                NaN  ...    955.321289   1012.984741    929.107239
# 2       NaN                NaN  ...           NaN           NaN           NaN
# 3   SW_LIFS  Life satisfaction  ...  52635.174960  50955.998320  43596.135540
# 4   SW_LIFS  Life satisfaction  ...  53291.127690  55123.849790  56762.729450
#
#            2016          2017          2018          2019          2020  \
# 0   5368.433659   5825.198813   6073.395195   5968.319557   4864.106008
# 1    942.881348    975.924560   1011.599670   1050.932373   1104.164429
# 2           NaN           NaN           NaN           NaN           NaN
# 3  42315.603710  45129.429300  46547.795180  46374.152750  43349.677860
# 4  57866.744930  59907.754260  62823.309440  65120.394660  63528.634300
#
#            2021          2022
# 0   4646.537921   5316.658385
# 1   1146.031982   1192.403809
# 2           NaN           NaN
# 3  52358.621640  54966.488840
# 4  70219.472450  76398.591740
#
# [5 rows x 91 columns]

# %%
#Let's plot the per Capita GDP, per the World Bank:
fig, ax1 = plt.subplots(1,1, figsize=(12, 10), dpi=300)

gdf_merged2.plot(ax = ax1, column = '2020', edgecolor='black', alpha=1, linewidth=1, scheme='quantiles', k=10)

ax1.set_axis_off()

# %% [markdown]
# ## Scatter Plots Again!

# %%
#Let's compare the data that with our Natural Earth Dataset to what we grabbed from the World Bank
#Nearly indistinguishable!
#############################

fig, ax1 = plt.subplots(1,2, figsize=(12, 6))

#Note, we size by population and color by GDP:
ax1[0].scatter(gdf_merged_noNaN.GDP_Per_Cap, gdf_merged_noNaN.Value, s=gdf_merged_noNaN.pop_est/2e5, c=gdf_merged_noNaN.GDP_Per_Cap,
               edgecolor='black', alpha=.8)

ax1[1].scatter(gdf_merged2['2020'], gdf_merged2.Value, s=gdf_merged2.pop_est/2e5, c=gdf_merged2['2020'], edgecolor='black', alpha=.8)

# %% [markdown]
# ### Descriptive Statistics?
#
# - We can describe our dataset as usual, but there's a catch: Each observation represents different population sizes

# %%
#Just a naive describe:
###

gdf_merged2['2020'].describe()
# Out:
# count       165.000000
# mean      13796.637572
# std       19711.077959
# min         216.827417
# 25%        1838.448124
# 50%        4897.264770
# 75%       16707.623010
# max      117370.496900
# Name: 2020, dtype: float64

# %%
## Let's get the *weighted* mean instead:
## Oh dear, it's just NaN
np.average(gdf_merged2['2020'], weights = gdf_merged2['pop_est'])
# Out:
# nan

# %%
#Let's drop the NaNs, for 2020:
gdf_merged2_noNaN = gdf_merged2.dropna(subset = '2020')

# %%
#Okay, at last!
###

np.average(gdf_merged2_noNaN['2020'], weights = gdf_merged2_noNaN['pop_est'])
# Out:
# 10939.728013907137

# %%
## And weighted standard deviation?

# %% [markdown]
# ## Distributions?
#
# - Let's make some histograms/kernel density estimates for life satisfaction and per capita GDP scores
# - But again, we have different population sizes, so should weight for this
# - Can do in seaborn!

# %%
import seaborn as sns

# %%
#Compare weighted vs. unweighted:
fig, ax1 = plt.subplots(1,2, figsize=(12, 5))

N = 25
#Unweighted:
#Note that bw_method can be 'scott', 'silverman', or a specific number; default is 'scott'
sns.histplot(data=gdf_merged2_noNaN, x="2020", bins=N, ax=ax1[0], stat="density")
sns.kdeplot(data=gdf_merged2_noNaN, x="2020", ax=ax1[0], color='black', linewidth=3, bw_method=.2)


#Weighted:
sns.histplot(data=gdf_merged2_noNaN, x="2020", weights='pop_est', bins=N, ax=ax1[1], stat="density")
sns.kdeplot(data=gdf_merged2_noNaN, x="2020", weights='pop_est', ax=ax1[1], color='black', linewidth=3, bw_method=.2) #'silverman')

plt.subplots_adjust(wspace=.3)

# %% [markdown]
# ## Linear Regression using scikit-learn
#
# - We'll skip the train/test split and just get the basic idea...

# %%
#Get the LinearRegression model
from sklearn.linear_model import LinearRegression

#And prep our data:
#Get our X and y as a single dataframe:
Xy = gdf_merged2[['2020', 'Value']]

#Let's also sort by '2020':
Xy = Xy.sort_values(by = '2020')

#And drop any observations with NaN in either column
Xy.dropna()
# Out:
#               2020  Value
# 32     5304.289129    5.7
# 25     5741.641249    4.9
# 29     6923.700197    6.1
# 124    8561.064333    4.9
# 27     8654.997325    6.0
# 18    10194.441410    5.5
# 34    12179.256670    6.3
# 10    13165.386340    6.2
# 113   15816.820400    6.1
# 115   16125.609410    6.0
# 123   17658.947300    5.8
# 119   18207.139640    6.2
# 152   19551.621160    6.5
# 118   20363.924410    6.4
# 131   22242.406420    5.8
# 153   22992.879380    6.9
# 120   23595.243680    6.5
# 150   25545.241000    6.5
# 132   26959.675440    6.5
# 96    31721.298020    5.8
# 141   31918.693490    6.5
# 43    39055.282930    6.7
# 155   39986.928630    6.1
# 143   40318.416920    6.8
# 136   41760.594780    7.3
# 3     43349.677860    7.0
# 76    44846.791600    7.2
# 129   45517.903820    6.8
# 121   46772.825350    7.3
# 114   48809.226880    7.2
# 151   49169.719340    7.9
# 137   51722.069000    7.1
# 130   52162.570120    7.5
# 110   52837.903980    7.3
# 144   58813.796980    7.6
# 142   60915.424400    7.5
# 4     63528.634300    7.0
# 21    68340.018100    7.3
# 133   85420.190860    7.0
# 127   85656.322670    7.5
# 128  117370.496900    7.4

# %%
#Get X and y:
X = Xy.dropna()['2020']
y = Xy.dropna()['Value']

# %%
#Make our model and train:
model = LinearRegression()

#If we try just this, we get an error:
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[180], line 5
#       2 model = LinearRegression()
#       4 #If we try just this, we get an error:
# ----> 5 model.fit(X, y)
#
# File ~\Anaconda3\envs\my_env\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\Anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 678 X, y = self._validate_data(
#     679     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     680 )
#     682 has_sw = sample_weight is not None
#     683 if has_sw:
#
# File ~\Anaconda3\envs\my_env\lib\site-packages\sklearn\base.py:621, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     619         y = check_array(y, input_name="y", **check_y_params)
#     620     else:
# --> 621         X, y = check_X_y(X, y, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\Anaconda3\envs\my_env\lib\site-packages\sklearn\utils\validation.py:1147, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142         estimator_name = _check_estimator_name(estimator)
#    1143     raise ValueError(
#    1144         f"{estimator_name} requires y to be passed, but the target y is None"
#    1145     )
# -> 1147 X = check_array(
#    1148     X,
#    1149     accept_sparse=accept_sparse,
#    1150     accept_large_sparse=accept_large_sparse,
#    1151     dtype=dtype,
#    1152     order=order,
#    1153     copy=copy,
#    1154     force_all_finite=force_all_finite,
#    1155     ensure_2d=ensure_2d,
#    1156     allow_nd=allow_nd,
#    1157     ensure_min_samples=ensure_min_samples,
#    1158     ensure_min_features=ensure_min_features,
#    1159     estimator=estimator,
#    1160     input_name="X",
#    1161 )
#    1163 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1165 check_consistent_length(X, y)
#
# File ~\Anaconda3\envs\my_env\lib\site-packages\sklearn\utils\validation.py:940, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     938     # If input is 1D raise error
#     939     if array.ndim == 1:
# --> 940         raise ValueError(
#     941             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     942             "Reshape your data either using array.reshape(-1, 1) if "
#     943             "your data has a single feature or array.reshape(1, -1) "
#     944             "if it contains a single sample.".format(array)
#     945         )
#     947 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#     948     raise ValueError(
#     949         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     950         "Convert your data to numeric values explicitly instead."
#     951     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[  5304.289129   5741.641249   6923.700197   8561.064333   8654.997325
#   10194.44141   12179.25667   13165.38634   15816.8204    16125.60941
#   17658.9473    18207.13964   19551.62116   20363.92441   22242.40642
#   22992.87938   23595.24368   25545.241     26959.67544   31721.29802
#   31918.69349   39055.28293   39986.92863   40318.41692   41760.59478
#   43349.67786   44846.7916    45517.90382   46772.82535   48809.22688
#   49169.71934   51722.069     52162.57012   52837.90398   58813.79698
#   60915.4244    63528.6343    68340.0181    85420.19086   85656.32267
#  117370.4969  ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
#Extract our values and reshape:
X = X.values
X = X.reshape(-1,1)

# %%
X.shape
# Out:
# (41, 1)

# %%
#Now try:
model.fit(X, y)
# Out:
# LinearRegression()

# %%
##Make some predictions and plot the result:
####

y_pred = model.predict(X)

#Plot:

fig, ax1 = plt.subplots(1,1, figsize=(6, 6))

#Note, we size by population and color by GDP:
ax1.scatter(gdf_merged2['2020'], gdf_merged2.Value, s=gdf_merged2.pop_est/2e5, c=gdf_merged2['2020'], edgecolor='black', alpha=.8)

ax1.plot(X, y_pred, linewidth=3, color='black')

# %% [markdown]
# ### But, let's add weights

# %%
#With weights:

#And prep our data again:
Xy = gdf_merged2[['2020', 'Value', 'pop_est']]

Xy = Xy.sort_values(by='2020')

#Get X and y:
X = Xy.dropna()['2020']
y = Xy.dropna()['Value']
pop = Xy.dropna()['pop_est']

X = X.values
X = X.reshape(-1,1)

#Fit with weights:
model.fit(X, y, sample_weight = pop)
# Out:
# LinearRegression()

# %%
##Make some predictions and plot the result:
####

y_pred_weighted = model.predict(X)

#Plot:

fig, ax1 = plt.subplots(1,1, figsize=(6, 6))

#Note, we size by population and color by GDP:
ax1.scatter(gdf_merged2['2020'], gdf_merged2.Value, s=gdf_merged2.pop_est/2e5, c=gdf_merged2['2020'], edgecolor='black', alpha=.8)

ax1.plot(X, y_pred, linewidth=3, color='black')
ax1.plot(X, y_pred_weighted, linewidth=3, color='red')
